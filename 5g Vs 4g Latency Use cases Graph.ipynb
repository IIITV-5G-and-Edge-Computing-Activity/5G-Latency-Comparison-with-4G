# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Data from the table
df = pd.read_csv('5gvs4g.csv')


# Plot settings
x = np.arange(len(categories))
width = 0.2

fig, ax = plt.subplots(figsize=(10, 6))
bar1 = ax.bar(x - width, min_5g, width, label='Min 5G', color='blue')
bar2 = ax.bar(x, min_4g, width, label='Min 4G', color='lightblue')
bar3 = ax.bar(x + width, max_5g, width, label='Max 5G', color='green')
bar4 = ax.bar(x + 2 * width, max_4g, width, label='Max 4G', color='lightgreen')

# Add average as a line plot for clarity
ax.plot(x, avg_5g, label='Avg 5G', marker='o', color='orange', linewidth=2)
ax.plot(x, avg_4g, label='Avg 4G', marker='o', color='red', linewidth=2)

# Labels and Title
ax.set_xlabel("Use Case")
ax.set_ylabel("Latency (ms)")
ax.set_title("Comparison of Latency Metrics for 5G and 4G")
ax.set_xticks(x)
ax.set_xticklabels(categories)
ax.legend()

# Display the graph
plt.tight_layout()
plt.show()
